# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
import json

# %%
with open('tiles.json') as tiles_file:
    tiles_data = json.load(tiles_file)
    for tile in tiles_data:
        print('Name: ' + tile['name'])
# Out:
# Name: 01A
# Name: 01B

# %%
canvas = Image.new('RGBA',(416,832))
img1 = Image.open('images/02B.png').rotate(90, expand=True)
img2 = Image.open('images/01B.png')
canvas.paste(img1,(0,0,0+img1.width,0+img1.height),img1)
canvas.paste(img2,(0,316,416,732),img2)
canvas
# Out:
# <PIL.Image.Image image mode=RGBA size=416x832 at 0x264EDFC9AC8>

# %%
tuple(map(round, (0.5,0.9)))
# Out:
# (0, 1)
